# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Bengaluru_House_Data.csv")

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
temp=df.head(100).copy()

# %%
temp.drop(["availability","location","society"],axis=1,inplace=True)

# %%
temp.drop("area_type",axis=1,inplace=True)

# %%
temp
# Out:
#          size total_sqft  bath  balcony   price
# 0       2 BHK       1056   2.0      1.0   39.07
# 1   4 Bedroom       2600   5.0      3.0  120.00
# 2       3 BHK       1440   2.0      3.0   62.00
# 3       3 BHK       1521   3.0      1.0   95.00
# 4       2 BHK       1200   2.0      1.0   51.00
# ..        ...        ...   ...      ...     ...
# 95      3 BHK       1540   3.0      2.0   90.00
# 96  4 Bedroom       2894   4.0      1.0  245.00
# 97      3 BHK       1330   2.0      1.0   48.00
# 98      2 BHK       1200   2.0      1.0   65.00
# 99  3 Bedroom       1200   3.0      1.0   90.00
#
# [100 rows x 5 columns]

# %%
list1=[int(i[0]) for i in temp["size"]]

# %%
temp["size"]=list1

# %%
temp
# Out:
#     size total_sqft  bath  balcony   price
# 0      2       1056   2.0      1.0   39.07
# 1      4       2600   5.0      3.0  120.00
# 2      3       1440   2.0      3.0   62.00
# 3      3       1521   3.0      1.0   95.00
# 4      2       1200   2.0      1.0   51.00
# ..   ...        ...   ...      ...     ...
# 95     3       1540   3.0      2.0   90.00
# 96     4       2894   4.0      1.0  245.00
# 97     3       1330   2.0      1.0   48.00
# 98     2       1200   2.0      1.0   65.00
# 99     3       1200   3.0      1.0   90.00
#
# [100 rows x 5 columns]

# %%
list1=[int(i) for i in temp["total_sqft"]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-a3a785ae496b> in <module>
# ----> 1 list1=[int(i) for i in temp["total_sqft"]]
#
# <ipython-input-19-a3a785ae496b> in <listcomp>(.0)
# ----> 1 list1=[int(i) for i in temp["total_sqft"]]
#
# ValueError: invalid literal for int() with base 10: '2100 - 2850'

# %%
temp
# Out:
#     size total_sqft  bath  balcony   price
# 0      2       1056   2.0      1.0   39.07
# 1      4       2600   5.0      3.0  120.00
# 2      3       1440   2.0      3.0   62.00
# 3      3       1521   3.0      1.0   95.00
# 4      2       1200   2.0      1.0   51.00
# ..   ...        ...   ...      ...     ...
# 95     3       1540   3.0      2.0   90.00
# 96     4       2894   4.0      1.0  245.00
# 97     3       1330   2.0      1.0   48.00
# 98     2       1200   2.0      1.0   65.00
# 99     3       1200   3.0      1.0   90.00
#
# [100 rows x 5 columns]

# %%
type(temp["total_sqft"][0])
# Out:
# str

# %%
temp["total_sqft"].fillna('1000',inplace=True)

# %%
list2=[]
for i in temp["total_sqft"]:
    if '-' in i:
        x=i[0:4]
        mean=float(x)
        list2.append(mean)
    else:
        list2.append(float(i))

# %%
len(list2)
# Out:
# 100

# %%
temp["total_sqft"]=list2

# %%
temp.drop('total_size',axis=1,inplace=True)

# %%
list3=[int(i[0]) for i in temp["size"]]

# %%
temp["size"]=list3

# %%
temp
# Out:
#     size  total_sqft  bath  balcony   price
# 0      2      1056.0   2.0      1.0   39.07
# 1      4      2600.0   5.0      3.0  120.00
# 2      3      1440.0   2.0      3.0   62.00
# 3      3      1521.0   3.0      1.0   95.00
# 4      2      1200.0   2.0      1.0   51.00
# ..   ...         ...   ...      ...     ...
# 95     3      1540.0   3.0      2.0   90.00
# 96     4      2894.0   4.0      1.0  245.00
# 97     3      1330.0   2.0      1.0   48.00
# 98     2      1200.0   2.0      1.0   65.00
# 99     3      1200.0   3.0      1.0   90.00
#
# [100 rows x 5 columns]

# %%
housing=pd.DataFrame()

# %%
list4=[1 for i in range(0,100)]

# %%
housing["x0"]=list4

# %%
housing
# Out:
#     x0
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# ..  ..
# 95   1
# 96   1
# 97   1
# 98   1
# 99   1
#
# [100 rows x 1 columns]

# %%
housing=housing.join(temp)

# %%
housing
# Out:
#     x0  size total_sqft  bath  balcony   price  total_size
# 0    1     2       1056   2.0      1.0   39.07      1056.0
# 1    1     4       2600   5.0      3.0  120.00      2600.0
# 2    1     3       1440   2.0      3.0   62.00      1440.0
# 3    1     3       1521   3.0      1.0   95.00      1521.0
# 4    1     2       1200   2.0      1.0   51.00      1200.0
# ..  ..   ...        ...   ...      ...     ...         ...
# 95   1     3       1540   3.0      2.0   90.00      1540.0
# 96   1     4       2894   4.0      1.0  245.00      2894.0
# 97   1     3       1330   2.0      1.0   48.00      1330.0
# 98   1     2       1200   2.0      1.0   65.00      1200.0
# 99   1     3       1200   3.0      1.0   90.00      1200.0
#
# [100 rows x 7 columns]

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
max=df["price"].max()
df[df["price"]==max]["location"]
# Out:
# 13067    Defence Colony
# Name: location, dtype: object

# %%
df.groupby("location").mean()
# Out:
#                           bath  balcony       price
# location
#  Anekal               1.000000      1.0   16.000000
#  Banaswadi            1.000000      0.0   35.000000
#  Basavangudi          1.000000      1.0   50.000000
#  Bhoganhalli          1.000000      0.0   22.890000
#  Devarabeesana Halli  2.666667      2.0  124.833333
# ...                        ...      ...         ...
# t.c palya             6.000000      3.0  160.000000
# tc.palya              2.000000      1.0   60.750000
# vinayakanagar         5.000000      2.0  200.000000
# white field,kadugodi  6.000000      NaN  275.000000
# whitefiled            2.000000      1.0   32.730000
#
# [1305 rows x 3 columns]
