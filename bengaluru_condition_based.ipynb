# %%
import pandas as pd

# %%
import numpy as np

# %%
temp=pd.read_csv("Bengaluru_House_Data_edited.csv")

# %%
temp
# Out:
#                 area_type   availability                  location       size  \
# 0    Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1              Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2          Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3    Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4    Super built-up  Area  Ready To Move                  Kothanur      2 BHK
# ..                    ...            ...                       ...        ...
# 990  Super built-up  Area         19-Jan               Mysore Road      2 BHK
# 991        Built-up  Area  Ready To Move                     Hoodi      2 BHK
# 992            Plot  Area  Ready To Move             Chikkabanavar  1 Bedroom
# 993            Plot  Area         18-Aug                      ITPL  3 Bedroom
# 994        Built-up  Area  Ready To Move         Somasundara Palya      2 BHK
#
# ...

# %%
temp.dropna(inplace=True)

# %%
temp
# Out:
#                 area_type   availability                  location       size  \
# 0    Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1              Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 3    Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 5    Super built-up  Area  Ready To Move                Whitefield      2 BHK
# 11             Plot  Area  Ready To Move                Whitefield  4 Bedroom
# ..                    ...            ...                       ...        ...
# 985  Super built-up  Area         18-Jul                 Hosa Road      2 BHK
# 986  Super built-up  Area  Ready To Move                  Sarjapur      1 BHK
# 989  Super built-up  Area  Ready To Move              Yeshwanthpur      1 BHK
# 991        Built-up  Area  Ready To Move                     Hoodi      2 BHK
# 994        Built-up  Area  Ready To Move         Somasundara Palya      2 BHK
#
# ...

# %%
temp.drop("availability",axis=1,inplace=True)

# %%
temp
# Out:
#                 area_type                  location       size  society  \
# 0    Super built-up  Area  Electronic City Phase II      2 BHK  Coomee
# 1              Plot  Area          Chikka Tirupathi  4 Bedroom  Theanmp
# 3    Super built-up  Area        Lingadheeranahalli      3 BHK  Soiewre
# 5    Super built-up  Area                Whitefield      2 BHK  DuenaTa
# 11             Plot  Area                Whitefield  4 Bedroom  Prrry M
# ..                    ...                       ...        ...      ...
# 985  Super built-up  Area                 Hosa Road      2 BHK  Mahesr
# 986  Super built-up  Area                  Sarjapur      1 BHK  DSousyl
# 989  Super built-up  Area              Yeshwanthpur      1 BHK  IBityin
# 991        Built-up  Area                     Hoodi      2 BHK  Goeur G
# 994        Built-up  Area         Somasundara Palya      2 BHK  Abeesmi
#
#     total_sqft  bath  balcony    price
# 0         1056   2.0      1.0   39.070
# ...

# %%
listsize=[int(i[0]) for i in temp["size"]]

# %%
temp["size"]=listsize

# %%
temp
# Out:
#                 area_type                  location  size  society total_sqft  \
# 0    Super built-up  Area  Electronic City Phase II     2  Coomee        1056
# 1              Plot  Area          Chikka Tirupathi     4  Theanmp       2600
# 3    Super built-up  Area        Lingadheeranahalli     3  Soiewre       1521
# 5    Super built-up  Area                Whitefield     2  DuenaTa       1170
# 11             Plot  Area                Whitefield     4  Prrry M       2785
# ..                    ...                       ...   ...      ...        ...
# 985  Super built-up  Area                 Hosa Road     2  Mahesr        1161
# 986  Super built-up  Area                  Sarjapur     1  DSousyl        645
# 989  Super built-up  Area              Yeshwanthpur     1  IBityin        665
# 991        Built-up  Area                     Hoodi     2  Goeur G       1425
# 994        Built-up  Area         Somasundara Palya     2  Abeesmi       1255
#
#      bath  balcony    price
# ...

# %%
listsqft=[]
for i in temp["total_sqft"]:
    if "-" in i:
        listsqft.append(float(i[0:i.find(" ")]))
    else:
        listsqft.append(float(i[0:]))

# %%
temp["total_sqft"]=listsqft

# %%
type(temp["total_sqft"][0])
# Out:
# numpy.float64

# %%
temp
# Out:
#                 area_type                  location  size  society  \
# 0    Super built-up  Area  Electronic City Phase II     2  Coomee
# 1              Plot  Area          Chikka Tirupathi     4  Theanmp
# 3    Super built-up  Area        Lingadheeranahalli     3  Soiewre
# 5    Super built-up  Area                Whitefield     2  DuenaTa
# 11             Plot  Area                Whitefield     4  Prrry M
# ..                    ...                       ...   ...      ...
# 985  Super built-up  Area                 Hosa Road     2  Mahesr
# 986  Super built-up  Area                  Sarjapur     1  DSousyl
# 989  Super built-up  Area              Yeshwanthpur     1  IBityin
# 991        Built-up  Area                     Hoodi     2  Goeur G
# 994        Built-up  Area         Somasundara Palya     2  Abeesmi
#
#      total_sqft  bath  balcony    price
# 0        1056.0   2.0      1.0   39.070
# 1        2600.0   5.0      3.0  120.000
# 3        1521.0   3.0      1.0   95.000
# ...

# %%
df=temp.copy()

# %%
df
# Out:
#                 area_type                  location  size  society  \
# 0    Super built-up  Area  Electronic City Phase II     2  Coomee
# 1              Plot  Area          Chikka Tirupathi     4  Theanmp
# 3    Super built-up  Area        Lingadheeranahalli     3  Soiewre
# 5    Super built-up  Area                Whitefield     2  DuenaTa
# 11             Plot  Area                Whitefield     4  Prrry M
# ..                    ...                       ...   ...      ...
# 985  Super built-up  Area                 Hosa Road     2  Mahesr
# 986  Super built-up  Area                  Sarjapur     1  DSousyl
# 989  Super built-up  Area              Yeshwanthpur     1  IBityin
# 991        Built-up  Area                     Hoodi     2  Goeur G
# 994        Built-up  Area         Somasundara Palya     2  Abeesmi
#
#      total_sqft  bath  balcony    price
# 0        1056.0   2.0      1.0   39.070
# 1        2600.0   5.0      3.0  120.000
# 3        1521.0   3.0      1.0   95.000
# ...

# %%
areatype=input('enter the area type')
loc=input("enter the location")
soc=input("enter the society name")
# Out:
# enter the area typePlot  Area
# enter the locationWhitefield
# enter the society nameCoomee

# %%
areatype
# Out:
# 'Plot  Area'

# %%
conddf=df[(df["area_type"]==areatype) & (df["society"]==soc) & (df["location"]==loc)].copy()

# %%
conddf
# Out:
# Empty DataFrame
# Columns: [area_type, location, size, society, total_sqft, bath, balcony, price]
# Index: []

# %%
listy=[]
for i in conddf["price"]:
    listy.append([i])

# %%
listy
# Out:
# []

# %%
conddf["x0"]=[1 for i in range(0,len(conddf))]

# %%
conddf
# Out:
# Empty DataFrame
# Columns: [area_type, location, size, society, total_sqft, bath, balcony, price, x0]
# Index: []
