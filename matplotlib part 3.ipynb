# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
fig=plt.figure()

# %%
ax=fig.add_axes([0,0,1,1])

# %%
x=[1,2,3,4,5,6,7]
y=[i**2 for i in x]

# %%
ax.plot(x,y,color="purple")

# %%
fig

# %%
ax2=fig.add_axes([0.1,0.1,1,1])

# %%
ax2.plot(y,x)

# %%
fig

# %%
fig1,axes=plt.subplots(figsize=(5,5),nrows=1,ncols=2)

# %%
plt.tight_layout()

# %%
axes[0].plot(x,y,color="red",linewidth=1,linestyle='--')

# %%
fig1

# %%
fig2=plt.figure(figsize=(5,5))

# %%
ax1=fig2.add_axes([0,0,1,1])
ax1.plot(x,y,label="squaerd",linestyle="--",marker='o')
ax1.plot(x,x,label="x to x")
ax1.legend(loc=0)

# %%
fig2
