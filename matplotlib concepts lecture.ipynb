# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline   
 #to see plots inside the jupyter notebook

# %%
import numpy as np

# %%
x=np.linspace(0,5,11)

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y=x**2

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("title")
# Out:
# Text(0.5, 1.0, 'title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot (1,2,2)
plt.plot(y,x,'b')

# %% [markdown]
# object oriented

# %%
fig=plt.figure()

# %%
axes=fig.add_axes([0.1,0.1,0.8,0.8])

# %%
axes.plot(x,y)

# %%
fig

# %%
fig=plt.figure()

# %%
axes1=fig.add_axes([0.1,0.1,0.8,0.8])

# %%
axes2=fig.add_axes([0.2,0.5,0.6,1])

# %%
fig

# %%
axes1.plot(x,x)

# %%
fig

# %%
axes2.plot(x,-x,'r')

# %%
fig

# %%
axes1.plot(x,-0.5*x+0.2)

# %%
fig

# %%
axes1.set_xlabel("x-axis")
# Out:
# Text(0.5, 3.200000000000003, 'x-axis')

# %%
fig

# %%
fig1=plt.figure()

# %%
axes21=fig1.add_axes([0.1,0.1,0.8,0.8])

# %%
fig1

# %%
plt.()
